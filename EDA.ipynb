# %%
#Se importan las librerías necesarias 

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from sklearn.feature_extraction.text import CountVectorizer

# %%
# Paso 1: Cargar el dataset
peliculas = pd.read_csv("C:/Users/Fede/Documents/henry/Labs/Fanny/peliculas.csv")

# %%
# Paso 2: Estadísticas descriptivas
print(peliculas.describe())
# Out:
#              budget    popularity       revenue       runtime  vote_average  \
# count  3.361500e+04  33615.000000  3.361500e+04  33425.000000  33615.000000
# mean   5.614863e+06      3.363904  1.456583e+07     95.312730      5.635187
# std    2.003590e+07      6.744894  7.388733e+07     38.634296      1.833527
# min    0.000000e+00      0.000000  0.000000e+00      0.000000      0.000000
# 25%    0.000000e+00      0.465673  0.000000e+00     87.000000      5.000000
# 50%    0.000000e+00      1.377893  0.000000e+00     95.000000      6.000000
# 75%    0.000000e+00      4.727102  0.000000e+00    107.000000      6.700000
# max    3.800000e+08    547.488298  2.787965e+09   1140.000000     10.000000
#
#          vote_count        return
# count  33615.000000  3.361500e+04
# mean     138.390391  6.378140e+02
# std      560.845605  7.336144e+04
# min        0.000000  0.000000e+00
# 25%        4.000000  0.000000e+00
# 50%       12.000000  0.000000e+00
# 75%       47.000000  0.000000e+00
# ...

# %%
# Paso 3: Distribuciones de variables numéricas
import seaborn as sns

# %%
# Paso 3: Distribuciones de todas las variables numéricas utilizando gráficos de densidad (KDE)
plt.figure(figsize=(10, 8))
sns.set(style="whitegrid")

# Obtener una lista de las columnas numéricas
numeric_columns = peliculas.select_dtypes(include=[np.number]).columns

# Crear gráficos de densidad para cada variable numérica
for column in numeric_columns:
    sns.histplot(data=reviews_dataset, x=column, kde=True, label=column)

plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title('Distribuciones de Variables Numéricas')
plt.legend()
plt.show()

# %%
# Paso 4: Matriz de correlación
correlation_matrix = peliculas.corr()
print(correlation_matrix)
# Out:
#                 budget  popularity   revenue   runtime  vote_average  \
# budget        1.000000    0.448968  0.772253  0.143023      0.085105
# popularity    0.448968    1.000000  0.506735  0.118837      0.145676
# revenue       0.772253    0.506735  1.000000  0.109529      0.095762
# runtime       0.143023    0.118837  0.109529  1.000000      0.162871
# vote_average  0.085105    0.145676  0.095762  0.162871      1.000000
# vote_count    0.680922    0.554012  0.814524  0.118565      0.136282
# return       -0.002427    0.000694  0.000678  0.001602      0.003315
#
#               vote_count    return
# budget          0.680922 -0.002427
# popularity      0.554012  0.000694
# revenue         0.814524  0.000678
# runtime         0.118565  0.001602
# vote_average    0.136282  0.003315
# vote_count      1.000000 -0.000844
# return         -0.000844  1.000000
# ...

# %%
# Nube de palabras para los títulos de películas
from wordcloud import WordCloud
import matplotlib.pyplot as plt

title_wordcloud = WordCloud(width=800, height=400, background_color='green').generate(' '.join(peliculas['title']))
plt.figure(figsize=(9, 4))
plt.imshow(title_wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
